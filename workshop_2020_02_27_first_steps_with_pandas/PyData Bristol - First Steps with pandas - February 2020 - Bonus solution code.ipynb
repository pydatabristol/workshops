# %% [markdown]
# # First Steps with pandas
# ### Bonus Exercises: Solution Code
# * **PyData Bristol Meetup:** https://www.meetup.com/PyData-Bristol/events/268081062/
# * **Date:** Thu 27th February 2020
# * **Instructor:** John Sandall
# * **Contact:** john@coefficient.ai / [@john_sandall](https://twitter.com/john_sandall)
#
# <div class="alert alert-info">
#     This workshop is sponsored by <a href="https://coefficient.ai/">Coefficient</a>. If you are interested in either Python training for your company or organisation, or in consultancy services to help accelerate delivery of your data science, analytics, data engineering or machine learning projects, please visit <a href="https://coefficient.ai/">https://coefficient.ai/</a> or you can contact me at <a href="mailto:john@coefficient.ai/">john@coefficient.ai</a>
# </div>
#
# ---

# %%
import pandas as pd
import seaborn as sns
# Out:
# /usr/local/anaconda3/lib/python3.7/site-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %% [markdown]
# ## Detailed EU Referendum Results Data
# Source: https://github.com/six50/pipeline/tree/master/data/eu_referendum/electoral_commission/results
#
# Work through the following at your own pace. Some of this will recap what you've just learned. Some will be new.

# %% [markdown]
# ---
# > Alternatively, in the cell below, you could download `EU-referendum-result-data.csv` to the same folder as this notebook and then run
# >
# > ```python
# > df = pd.read_csv('EU-referendum-result-data.csv')
# > ```
# ---

# %%
df = pd.read_csv('https://s3-eu-west-1.amazonaws.com/sixfifty/EU-referendum-result-data.csv')
df
# Out:
#       id Region_Code                    Region  Area_Code             Area  \
# 0    108   E12000006                      East  E06000031     Peterborough
# 1    109   E12000006                      East  E06000032            Luton
# 2    112   E12000006                      East  E06000033  Southend-on-Sea
# 3    113   E12000006                      East  E06000034         Thurrock
# 4    110   E12000006                      East  E06000055          Bedford
# ..   ...         ...                       ...        ...              ...
# 377   65   E12000003  Yorkshire and The Humber  E08000032         Bradford
# 378   66   E12000003  Yorkshire and The Humber  E08000033       Calderdale
# 379   67   E12000003  Yorkshire and The Humber  E08000034         Kirklees
# 380   68   E12000003  Yorkshire and The Humber  E08000035            Leeds
# 381   69   E12000003  Yorkshire and The Humber  E08000036        Wakefield
#
#      Electorate  ExpectedBallots  VerifiedBallotPapers  Pct_Turnout  \
# 0        120892            87474                 87469        72.35
# 1        127612            84633                 84636        66.31
# 2        128856            93948                 93939        72.90
# 3        109897            79969                 79954        72.75
# 4        119530            86136                 86136        72.06
# ..          ...              ...                   ...          ...
# 377      342817           228729                228729        66.72
# 378      149195           106005                106008        71.05
# 379      307081           217460                217449        70.80
# 380      543033           387730                387730        71.39
# 381      246096           175261                175259        71.17
#
#      Votes_Cast  ...  Remain   Leave  Rejected_Ballots  No_official_mark  \
# 0         87469  ...   34176   53216                77                 0
# 1         84616  ...   36708   47773               135                 0
# 2         93939  ...   39348   54522                69                 0
# 3         79950  ...   22151   57765                34                 0
# 4         86135  ...   41497   44569                69                 0
# ..          ...  ...     ...     ...               ...               ...
# 377      228727  ...  104575  123913               239                 0
# 378      106004  ...   46950   58975                79                 0
# 379      217428  ...   98485  118755               188                 0
# 380      387677  ...  194863  192474               340                39
# 381      175155  ...   58877  116165               113                 0
#
#      Voting_for_both_answers  Writing_or_mark  Unmarked_or_void  Pct_Remain  \
# 0                         32                7                38       39.11
# 1                         85                0                50       43.45
# 2                         21                0                48       41.92
# 3                          8                3                23       27.72
# 4                         26                1                42       48.22
# ..                       ...              ...               ...         ...
# 377                      121                5               113       45.77
# 378                       22               15                42       44.32
# 379                       86                7                95       45.33
# 380                      116                8               177       50.31
# 381                       46                4                63       33.64
#
#      Pct_Leave  Pct_Rejected
# 0        60.89          0.09
# 1        56.55          0.16
# 2        58.08          0.07
# 3        72.28          0.04
# 4        51.78          0.08
# ..         ...           ...
# 377      54.23          0.10
# 378      55.68          0.07
# 379      54.67          0.09
# 380      49.69          0.09
# 381      66.36          0.06
#
# [382 rows x 21 columns]

# %%
df.shape
# Out:
# (382, 21)

# %%
df.columns
# Out:
# Index(['id', 'Region_Code', 'Region', 'Area_Code', 'Area', 'Electorate',
#        'ExpectedBallots', 'VerifiedBallotPapers', 'Pct_Turnout', 'Votes_Cast',
#        'Valid_Votes', 'Remain', 'Leave', 'Rejected_Ballots',
#        'No_official_mark', 'Voting_for_both_answers', 'Writing_or_mark',
#        'Unmarked_or_void', 'Pct_Remain', 'Pct_Leave', 'Pct_Rejected'],
#       dtype='object')

# %%
df.Electorate
# Out:
# 0      120892
# 1      127612
# 2      128856
# 3      109897
# 4      119530
#         ...
# 377    342817
# 378    149195
# 379    307081
# 380    543033
# 381    246096
# Name: Electorate, Length: 382, dtype: int64

# %%
df.head()
# Also results.tail()
# Out:
#     id Region_Code Region  Area_Code             Area  Electorate  \
# 0  108   E12000006   East  E06000031     Peterborough      120892
# 1  109   E12000006   East  E06000032            Luton      127612
# 2  112   E12000006   East  E06000033  Southend-on-Sea      128856
# 3  113   E12000006   East  E06000034         Thurrock      109897
# 4  110   E12000006   East  E06000055          Bedford      119530
#
#    ExpectedBallots  VerifiedBallotPapers  Pct_Turnout  Votes_Cast  ...  \
# 0            87474                 87469        72.35       87469  ...
# 1            84633                 84636        66.31       84616  ...
# 2            93948                 93939        72.90       93939  ...
# 3            79969                 79954        72.75       79950  ...
# 4            86136                 86136        72.06       86135  ...
#
#    Remain  Leave  Rejected_Ballots  No_official_mark  Voting_for_both_answers  \
# 0   34176  53216                77                 0                       32
# 1   36708  47773               135                 0                       85
# 2   39348  54522                69                 0                       21
# 3   22151  57765                34                 0                        8
# 4   41497  44569                69                 0                       26
#
#    Writing_or_mark  Unmarked_or_void  Pct_Remain  Pct_Leave  Pct_Rejected
# 0                7                38       39.11      60.89          0.09
# 1                0                50       43.45      56.55          0.16
# 2                0                48       41.92      58.08          0.07
# 3                3                23       27.72      72.28          0.04
# 4                1                42       48.22      51.78          0.08
#
# [5 rows x 21 columns]

# %%
# This gives the first three rows.
df[:3]
# Out:
#     id Region_Code Region  Area_Code             Area  Electorate  \
# 0  108   E12000006   East  E06000031     Peterborough      120892
# 1  109   E12000006   East  E06000032            Luton      127612
# 2  112   E12000006   East  E06000033  Southend-on-Sea      128856
#
#    ExpectedBallots  VerifiedBallotPapers  Pct_Turnout  Votes_Cast  ...  \
# 0            87474                 87469        72.35       87469  ...
# 1            84633                 84636        66.31       84616  ...
# 2            93948                 93939        72.90       93939  ...
#
#    Remain  Leave  Rejected_Ballots  No_official_mark  Voting_for_both_answers  \
# 0   34176  53216                77                 0                       32
# 1   36708  47773               135                 0                       85
# 2   39348  54522                69                 0                       21
#
#    Writing_or_mark  Unmarked_or_void  Pct_Remain  Pct_Leave  Pct_Rejected
# 0                7                38       39.11      60.89          0.09
# 1                0                50       43.45      56.55          0.16
# 2                0                48       41.92      58.08          0.07
#
# [3 rows x 21 columns]

# %% [markdown]
# > **Exercise:** What's the difference here between `iloc` and `loc`? Can you figure it out?

# %%
# Note what iloc[0] gives you...
df.iloc[0]
# Out:
# id                                  108
# Region_Code                   E12000006
# Region                             East
# Area_Code                     E06000031
# Area                       Peterborough
# Electorate                       120892
# ExpectedBallots                   87474
# VerifiedBallotPapers              87469
# Pct_Turnout                       72.35
# Votes_Cast                        87469
# Valid_Votes                       87392
# Remain                            34176
# Leave                             53216
# Rejected_Ballots                     77
# No_official_mark                      0
# Voting_for_both_answers              32
# Writing_or_mark                       7
# Unmarked_or_void                     38
# Pct_Remain                        39.11
# Pct_Leave                         60.89
# Pct_Rejected                       0.09
# Name: 0, dtype: object

# %%
# Now see how iloc[0] changes when applied to sorted data...
df.sort_values('Electorate').iloc[0]
# Out:
# id                                     101
# Region_Code                      E12000009
# Region                          South West
# Area_Code                        E06000053
# Area                       Isles of Scilly
# Electorate                            1799
# ExpectedBallots                       1424
# VerifiedBallotPapers                  1424
# Pct_Turnout                          79.16
# Votes_Cast                            1424
# Valid_Votes                           1424
# Remain                                 803
# Leave                                  621
# Rejected_Ballots                         0
# No_official_mark                         0
# Voting_for_both_answers                  0
# Writing_or_mark                          0
# Unmarked_or_void                         0
# Pct_Remain                           56.39
# Pct_Leave                            43.61
# Pct_Rejected                             0
# Name: 281, dtype: object

# %%
# And now what's loc[0] giving you? Can you guess what iloc and loc are doing?
df.sort_values('Electorate').loc[0]
# Out:
# id                                  108
# Region_Code                   E12000006
# Region                             East
# Area_Code                     E06000031
# Area                       Peterborough
# Electorate                       120892
# ExpectedBallots                   87474
# VerifiedBallotPapers              87469
# Pct_Turnout                       72.35
# Votes_Cast                        87469
# Valid_Votes                       87392
# Remain                            34176
# Leave                             53216
# Rejected_Ballots                     77
# No_official_mark                      0
# Voting_for_both_answers              32
# Writing_or_mark                       7
# Unmarked_or_void                     38
# Pct_Remain                        39.11
# Pct_Leave                         60.89
# Pct_Rejected                       0.09
# Name: 0, dtype: object

# %% [markdown]
# ---

# %%
# How to select multiple columns
df[['Area', 'Leave', 'Remain']]
# Out:
#                 Area   Leave  Remain
# 0       Peterborough   53216   34176
# 1              Luton   47773   36708
# 2    Southend-on-Sea   54522   39348
# 3           Thurrock   57765   22151
# 4            Bedford   44569   41497
# ..               ...     ...     ...
# 377         Bradford  123913  104575
# 378       Calderdale   58975   46950
# 379         Kirklees  118755   98485
# 380            Leeds  192474  194863
# 381        Wakefield  116165   58877
#
# [382 rows x 3 columns]

# %%
df.describe()
# Out:
#                id    Electorate  ExpectedBallots  VerifiedBallotPapers  \
# count  382.000000  3.820000e+02       382.000000            382.000000
# mean   191.500000  1.217278e+05     87904.429319          87900.620419
# std    110.418145  9.706175e+04     63611.874911          63605.668481
# min      1.000000  1.799000e+03      1424.000000           1424.000000
# 25%     96.250000  7.252375e+04     54878.500000          54877.500000
# 50%    191.500000  9.642550e+04     72544.500000          72544.000000
# 75%    286.750000  1.413798e+05    104436.500000         104436.500000
# max    382.000000  1.260955e+06    790647.000000         790523.000000
#
#        Pct_Turnout     Votes_Cast    Valid_Votes         Remain  \
# count   382.000000     382.000000     382.000000     382.000000
# mean     73.754764   87898.801047   87832.416230   42254.557592
# std       5.099413   63603.499333   63554.624962   35622.620732
# min      56.250000    1424.000000    1424.000000     803.000000
# 25%      70.270000   54875.500000   54844.250000   23535.250000
# 50%      74.345000   72544.500000   72511.500000   33475.000000
# 75%      77.905000  104436.500000  104332.000000   48245.500000
# max      83.640000  790523.000000  790149.000000  440707.000000
#
#                Leave  Rejected_Ballots  No_official_mark  \
# count     382.000000        382.000000        382.000000
# mean    45577.858639         66.384817          0.607330
# std     31308.892098         59.451306          2.851117
# min       621.000000          0.000000          0.000000
# 25%     28668.500000         33.250000          0.000000
# 50%     37573.500000         46.500000          0.000000
# 75%     54137.500000         74.000000          0.000000
# max    349442.000000        614.000000         39.000000
#
#        Voting_for_both_answers  Writing_or_mark  Unmarked_or_void  Pct_Remain  \
# count               382.000000       382.000000        382.000000  382.000000
# mean                 23.780105         2.188482         39.808901   47.010995
# std                  27.232427         3.306888         32.476240   10.696521
# min                   0.000000         0.000000          0.000000   24.440000
# 25%                  10.000000         0.000000         21.000000   39.655000
# 50%                  16.000000         1.000000         30.000000   45.735000
# 75%                  27.000000         3.000000         45.000000   52.857500
# max                 311.000000        35.000000        286.000000   95.910000
#
#         Pct_Leave  Pct_Rejected
# count  382.000000    382.000000
# mean    52.989005      0.073037
# std     10.696521      0.027811
# min      4.090000      0.000000
# 25%     47.142500      0.060000
# 50%     54.265000      0.070000
# 75%     60.345000      0.080000
# max     75.560000      0.240000

# %%
df.Region.unique()
# Out:
# array(['East', 'East Midlands', 'London', 'North East', 'North West',
#        'Northern Ireland', 'Scotland', 'South East', 'South West',
#        'Wales', 'West Midlands', 'Yorkshire and The Humber'], dtype=object)

# %%
# We can apply various summary statistics to any column
df.Electorate.sum()
# Out:
# 46500001

# %%
df.Electorate.mean()
# Out:
# 121727.75130890052

# %%
# We can also "group by" any column
df.groupby('Region')[['Leave', 'Remain']].mean()
# Out:
#                                   Leave         Remain
# Region
# East                       40007.808511   30821.617021
# East Midlands              36886.975000   25825.900000
# London                     45855.515152   68591.484848
# North East                 64841.916667   46882.916667
# North West                 50433.974359   43564.615385
# Northern Ireland          349442.000000  440707.000000
# Scotland                   31822.562500   51912.218750
# South East                 38327.835821   35697.283582
# South West                 43939.763158   39553.131579
# Wales                      38844.181818   35106.681818
# West Midlands              58522.900000   40239.166667
# Yorkshire and The Humber   75282.714286   55157.047619

# %% [markdown]
# Finally, we can import/export very easily in pandas:
# - Import: `pd.read_csv()` `pd.read_excel()`, `pd.read_sql()`, `pd.read_json()`, `pd.read_html()`
# - Export: `df.to_csv()`, `df.to_excel()`, `df.to_sql()`, `df.to_json()`
# - Many more formats are available! https://pandas.pydata.org/pandas-docs/stable/io.html

# %%
# Let's export this as a Excel file
df.to_excel('EU_ref_results-created_by_pandas.xlsx', index=False)
# This will be found in the same directory as this .ipynb file

# %% [markdown]
# ### Exercises
# Complete the cells below for each question in turn.

# %% [markdown]
# > **Exercise 1.** Add a column called `Outcome` containing either "Leave" or "Remain" as appropriate, then return only those rows that have `Outcome = Leave`. Tips:
# > - First create a function that accepts a number and returns `"Leave"` if the number is less than 50, otherwise returns "Remain".
# > - Apply this function to the `Pct_Remain` column.
# > - Assign the result to a new column called `Outcome`.
# > - Use your new column to filter to Leave areas only (or you could use `.query()`).

# %%
def leave_or_remain(x):
    return "Remain" if x > 50 else "Leave"

# %%
df['Outcome'] = df.Pct_Remain.apply(leave_or_remain)

# %%
df[df.Outcome == 'Leave']
# Out:
#       id Region_Code                    Region  Area_Code             Area  \
# 0    108   E12000006                      East  E06000031     Peterborough
# 1    109   E12000006                      East  E06000032            Luton
# 2    112   E12000006                      East  E06000033  Southend-on-Sea
# 3    113   E12000006                      East  E06000034         Thurrock
# 4    110   E12000006                      East  E06000055          Bedford
# ..   ...         ...                       ...        ...              ...
# 376   52   E12000003  Yorkshire and The Humber  E08000019        Sheffield
# 377   65   E12000003  Yorkshire and The Humber  E08000032         Bradford
# 378   66   E12000003  Yorkshire and The Humber  E08000033       Calderdale
# 379   67   E12000003  Yorkshire and The Humber  E08000034         Kirklees
# 381   69   E12000003  Yorkshire and The Humber  E08000036        Wakefield
#
#      Electorate  ExpectedBallots  VerifiedBallotPapers  Pct_Turnout  \
# 0        120892            87474                 87469        72.35
# 1        127612            84633                 84636        66.31
# 2        128856            93948                 93939        72.90
# 3        109897            79969                 79954        72.75
# 4        119530            86136                 86136        72.06
# ..          ...              ...                   ...          ...
# 376      396406           266954                266951        67.34
# 377      342817           228729                228729        66.72
# 378      149195           106005                106008        71.05
# 379      307081           217460                217449        70.80
# 381      246096           175261                175259        71.17
#
#      Votes_Cast  ...   Leave  Rejected_Ballots  No_official_mark  \
# 0         87469  ...   53216                77                 0
# 1         84616  ...   47773               135                 0
# 2         93939  ...   54522                69                 0
# 3         79950  ...   57765                34                 0
# 4         86135  ...   44569                69                 0
# ..          ...  ...     ...               ...               ...
# 376      266951  ...  136018               198                 0
# 377      228727  ...  123913               239                 0
# 378      106004  ...   58975                79                 0
# 379      217428  ...  118755               188                 0
# 381      175155  ...  116165               113                 0
#
#      Voting_for_both_answers  Writing_or_mark  Unmarked_or_void  Pct_Remain  \
# 0                         32                7                38       39.11
# 1                         85                0                50       43.45
# 2                         21                0                48       41.92
# 3                          8                3                23       27.72
# 4                         26                1                42       48.22
# ..                       ...              ...               ...         ...
# 376                       76                6               116       49.01
# 377                      121                5               113       45.77
# 378                       22               15                42       44.32
# 379                       86                7                95       45.33
# 381                       46                4                63       33.64
#
#      Pct_Leave  Pct_Rejected  Outcome
# 0        60.89          0.09    Leave
# 1        56.55          0.16    Leave
# 2        58.08          0.07    Leave
# 3        72.28          0.04    Leave
# 4        51.78          0.08    Leave
# ..         ...           ...      ...
# 376      50.99          0.07    Leave
# 377      54.23          0.10    Leave
# 378      55.68          0.07    Leave
# 379      54.67          0.09    Leave
# 381      66.36          0.06    Leave
#
# [263 rows x 22 columns]

# %%
df.query('Outcome == "Leave"')
# Out:
#       id Region_Code                    Region  Area_Code             Area  \
# 0    108   E12000006                      East  E06000031     Peterborough
# 1    109   E12000006                      East  E06000032            Luton
# 2    112   E12000006                      East  E06000033  Southend-on-Sea
# 3    113   E12000006                      East  E06000034         Thurrock
# 4    110   E12000006                      East  E06000055          Bedford
# ..   ...         ...                       ...        ...              ...
# 376   52   E12000003  Yorkshire and The Humber  E08000019        Sheffield
# 377   65   E12000003  Yorkshire and The Humber  E08000032         Bradford
# 378   66   E12000003  Yorkshire and The Humber  E08000033       Calderdale
# 379   67   E12000003  Yorkshire and The Humber  E08000034         Kirklees
# 381   69   E12000003  Yorkshire and The Humber  E08000036        Wakefield
#
#      Electorate  ExpectedBallots  VerifiedBallotPapers  Pct_Turnout  \
# 0        120892            87474                 87469        72.35
# 1        127612            84633                 84636        66.31
# 2        128856            93948                 93939        72.90
# 3        109897            79969                 79954        72.75
# 4        119530            86136                 86136        72.06
# ..          ...              ...                   ...          ...
# 376      396406           266954                266951        67.34
# 377      342817           228729                228729        66.72
# 378      149195           106005                106008        71.05
# 379      307081           217460                217449        70.80
# 381      246096           175261                175259        71.17
#
#      Votes_Cast  ...   Leave  Rejected_Ballots  No_official_mark  \
# 0         87469  ...   53216                77                 0
# 1         84616  ...   47773               135                 0
# 2         93939  ...   54522                69                 0
# 3         79950  ...   57765                34                 0
# 4         86135  ...   44569                69                 0
# ..          ...  ...     ...               ...               ...
# 376      266951  ...  136018               198                 0
# 377      228727  ...  123913               239                 0
# 378      106004  ...   58975                79                 0
# 379      217428  ...  118755               188                 0
# 381      175155  ...  116165               113                 0
#
#      Voting_for_both_answers  Writing_or_mark  Unmarked_or_void  Pct_Remain  \
# 0                         32                7                38       39.11
# 1                         85                0                50       43.45
# 2                         21                0                48       41.92
# 3                          8                3                23       27.72
# 4                         26                1                42       48.22
# ..                       ...              ...               ...         ...
# 376                       76                6               116       49.01
# 377                      121                5               113       45.77
# 378                       22               15                42       44.32
# 379                       86                7                95       45.33
# 381                       46                4                63       33.64
#
#      Pct_Leave  Pct_Rejected  Outcome
# 0        60.89          0.09    Leave
# 1        56.55          0.16    Leave
# 2        58.08          0.07    Leave
# 3        72.28          0.04    Leave
# 4        51.78          0.08    Leave
# ..         ...           ...      ...
# 376      50.99          0.07    Leave
# 377      54.23          0.10    Leave
# 378      55.68          0.07    Leave
# 379      54.67          0.09    Leave
# 381      66.36          0.06    Leave
#
# [263 rows x 22 columns]

# %% [markdown]
# > **Exercise 2.** How many areas have an electorate greater than 500,000 people?

# %%
# N.B. The len() function gives the length of any Python object, for example
print(len([1, 2, 3]))
print(len(df))
# Out:
# 3
# 382

# %%
len(df[df.Electorate > 500000])
# Out:
# 3

# %% [markdown]
# > **Exercise 3.** What's the maximum Pct_Rejected? Where was this?
# > - Option A: use `.max()` and then filter to where `Pct_Rejected` equals this value
# > - Option B: use `.sort_values()` with `.head(1)`

# %%
# Option A
print(df.Pct_Rejected.max())
df[df.Pct_Rejected == df.Pct_Rejected.max()]
# Out:
# 0.24
#     id Region_Code         Region  Area_Code       Area  Electorate  \
# 48  89   E12000004  East Midlands  E06000016  Leicester      213819
#
#     ExpectedBallots  VerifiedBallotPapers  Pct_Turnout  Votes_Cast  ...  \
# 48           139319                139309        65.15      139307  ...
#
#     Leave  Rejected_Ballots  No_official_mark  Voting_for_both_answers  \
# 48  67992               335                 0                      154
#
#     Writing_or_mark  Unmarked_or_void  Pct_Remain  Pct_Leave  Pct_Rejected  \
# 48                8               173       51.08      48.92          0.24
#
#     Outcome
# 48   Remain
#
# [1 rows x 22 columns]

# %%
# Option B
df.sort_values('Pct_Rejected', ascending=False).head(1)
# Out:
#     id Region_Code         Region  Area_Code       Area  Electorate  \
# 48  89   E12000004  East Midlands  E06000016  Leicester      213819
#
#     ExpectedBallots  VerifiedBallotPapers  Pct_Turnout  Votes_Cast  ...  \
# 48           139319                139309        65.15      139307  ...
#
#     Leave  Rejected_Ballots  No_official_mark  Voting_for_both_answers  \
# 48  67992               335                 0                      154
#
#     Writing_or_mark  Unmarked_or_void  Pct_Remain  Pct_Leave  Pct_Rejected  \
# 48                8               173       51.08      48.92          0.24
#
#     Outcome
# 48   Remain
#
# [1 rows x 22 columns]

# %% [markdown]
# > **Exercise 4.** Which areas have Region equals "Scotland" and `Pct_Leave` is greater than 49?

# %%
(df.Region == 'Scotland').head()
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# Name: Region, dtype: bool

# %%
(df.Region == 'Scotland') & (df.Pct_Leave > 49)
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 377    False
# 378    False
# 379    False
# 380    False
# 381    False
# Length: 382, dtype: bool

# %%
df[(df.Region == 'Scotland') & (df.Pct_Leave > 49)]
# Out:
#       id Region_Code    Region  Area_Code   Area  Electorate  ExpectedBallots  \
# 183  168   S92000003  Scotland  S12000020  Moray       71370            48148
#
#      VerifiedBallotPapers  Pct_Turnout  Votes_Cast  ...  Leave  \
# 183                 48139        67.45       48139  ...  23992
#
#      Rejected_Ballots  No_official_mark  Voting_for_both_answers  \
# 183                33                 0                       16
#
#      Writing_or_mark  Unmarked_or_void  Pct_Remain  Pct_Leave  Pct_Rejected  \
# 183                3                14       50.13      49.87          0.07
#
#      Outcome
# 183   Remain
#
# [1 rows x 22 columns]

# %% [markdown]
# > **Exercise 5.** Calculate the total Leave/Remain votes cast by Region.

# %%
df.groupby('Region')[['Remain', 'Leave']].sum()
# Out:
#                            Remain    Leave
# Region
# East                      1448616  1880367
# East Midlands             1033036  1475479
# London                    2263519  1513232
# North East                 562595   778103
# North West                1699020  1966925
# Northern Ireland           440707   349442
# Scotland                  1661191  1018322
# South East                2391718  2567965
# South West                1503019  1669711
# Wales                      772347   854572
# West Midlands             1207175  1755687
# Yorkshire and The Humber  1158298  1580937

# %% [markdown]
# > **Exercise 6.** Using your scatterplot code from earlier, plot `Pct_Turnout` (x-axis) against `Pct_Rejected` (y-axis).

# %%
sns.scatterplot(x='Pct_Turnout', y='Pct_Rejected', data=df)

# %% [markdown]
# > **Exercise 7.** Add `hue='Outcome'` to colour code this by Remain/Leave.

# %%
sns.scatterplot(x='Pct_Turnout', y='Pct_Rejected', hue='Outcome', data=df)
